# %%
#import essential libaries
import yfinance as yf
import pandas as pd

# %% [markdown]
# Using the yfinance Library to Extract Stock Data(Apple,Amd)

# %%
#ticker module creates an object that helps to work on extraction of data from https://pypi.org/user/ranaroussi/
apple = yf.Ticker("AAPL")

# %% [markdown]
# Using the attribute  <code>info</code> we can extract information about the stock as a Python dictionary.

# %%
#to get information about apple on yfinance
apple_info=apple.info
apple_info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 154000,
# ...

# %%
#country info
apple_info['country']
# Out:
# 'United States'

# %% [markdown]
# A share is the single smallest part of a company's stock  that you can buy, the prices of these shares fluctuate over time. Using the <code>history()</code> method we can get the share price of the stock over a certain period of time. Using the `period` paramete
# r we can set how far back from the present to get data. The options for `period` are 1 day (1d), 5d, 1 month (1mo) , 3mo, 6mo, 1 year (1y), 2y, 5y, 10y, ytd, and max.

# %%
#histy of rise and clsoe and open stock market prices
apple_share_price_data = apple.history(period="max")
apple_share_price_data
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100178    0.100614    0.100178    0.100178  469033600
# 1980-12-15    0.095388    0.095388    0.094952    0.094952  175884800
# 1980-12-16    0.088418    0.088418    0.087983    0.087983  105728000
# 1980-12-17    0.090160    0.090596    0.090160    0.090160   86441600
# 1980-12-18    0.092774    0.093210    0.092774    0.092774   73449600
# ...                ...         ...         ...         ...        ...
# 2022-07-20  151.119995  153.720001  150.369995  153.039993   64823400
# 2022-07-21  154.500000  155.570007  151.940002  155.350006   65086600
# 2022-07-22  155.389999  156.279999  153.410004  154.089996   66625400
# 2022-07-25  154.009995  155.039993  152.279999  152.949997   53515000
# 2022-07-26  152.264999  153.085007  150.800003  151.449997   37203540
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %% [markdown]
# The format that the data is returned in is a Pandas DataFrame. With the `Date` as the index the share `Open`, `High`, `Low`, `Close`, `Volume`, and `Stock Splits` are given for each day.

# %%
#top of data
apple_share_price_data.head()
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 1980-12-12  0.100178  0.100614  0.100178  0.100178  469033600        0.0
# 1980-12-15  0.095388  0.095388  0.094952  0.094952  175884800        0.0
# 1980-12-16  0.088418  0.088418  0.087983  0.087983  105728000        0.0
# 1980-12-17  0.090160  0.090596  0.090160  0.090160   86441600        0.0
# 1980-12-18  0.092774  0.093210  0.092774  0.092774   73449600        0.0
#
#             Stock Splits
# Date
# 1980-12-12           0.0
# 1980-12-15           0.0
# 1980-12-16           0.0
# 1980-12-17           0.0
# 1980-12-18           0.0

# %% [markdown]
# We can reset the index of the DataFrame with the `reset_index` function. We also set the `inplace` paramter to `True` so the change takes place to the DataFrame itself.

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
apple_share_price_data.plot(x="Date", y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apple.dividends
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# 2021-11-05    0.220000
# 2022-02-04    0.220000
# 2022-05-06    0.230000
# Name: Dividends, Length: 75, dtype: float64

# %%
apple.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amd = yf.Ticker("AMD")

# %%
amd_info=amd.info
amd_info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 15500,
# ...

# %%
amd_info['country']
#testtesttest
# Out:
# 'United States'

# %%
amd_info['sector']
# Out:
# 'Technology'

# %%
amd_share_price_data = amd.history(period="max")
amd_share_price_data
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 1980-03-17   0.000000   3.302083   3.125000   3.145833    219600          0
# 1980-03-18   0.000000   3.125000   2.937500   3.031250    727200          0
# 1980-03-19   0.000000   3.083333   3.020833   3.041667    295200          0
# 1980-03-20   0.000000   3.062500   3.010417   3.010417    159600          0
# 1980-03-21   0.000000   3.020833   2.906250   2.916667    130800          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-07-20  85.389999  89.919998  85.080002  89.430000  88348600          0
# 2022-07-21  89.599998  91.580002  88.220001  91.089996  90449300          0
# 2022-07-22  90.199997  90.690002  87.040001  88.099998  76952700          0
# 2022-07-25  86.570000  87.599998  85.120003  87.540001  70034300          0
# 2022-07-26  87.000000  87.749001  84.709999  85.073997  59476726          0
#
#             Stock Splits
# Date
# ...

# %%
amd_share_price_data = amd.history(period="day")
amd_share_price_data
# Out:
#             Open       High        Low      Close    Volume  Dividends  \
# Date
# 2022-07-26  87.0  87.749001  84.709999  85.014999  59622865          0
#
#             Stock Splits
# Date
# 2022-07-26             0

# %%
try:
    amd_share_price_data.plot(x="Date", y="Open")
except:
    print ("no output")
# Out:
# no output

# %%
amd.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
